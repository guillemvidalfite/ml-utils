# %% [markdown]
# #### Load original csv datasets into dataframes:

# %%
import pandas as pd

# %%
df_ds1 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds1-050-213-Z1-UB64-130-400-401-1.1-620168_213_1_2_1_1_1_2.csv')
df_ds2 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds2-050-213-Z1-UB64-170-100-101-1.1-610836_213_1_2_1_2_1_1.csv')
df_ds3 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds3-050-213-Z1-UB64-130-400-401-1.1-620168_213_1_2_1_2_1_2.csv')
df_ds4 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds4-050-213-Z1-UB64-110-200-201-2.1-620625_213_1_1_1_1_1_1.csv')
df_ds5 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds5-050-213-Z1-UB64-060-400-401-2.1-610762_213_3_1_1_2_1_2.csv')
df_ds6 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds6-050-213-Z1-UB64-040-200-201-1.1-610445_213_3_2_1_2_1_1.csv')
df_ds8 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds8-050-213-Z1-UB64-110-100-101-1.1-610456_213_3_1_1_1_1_1.csv')
df_ds9 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds9-050-213-Z1-UB63-140-100-101-1.1-620671_213_1_2_1_2_1_1.csv')
df_ds10 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds10-050-213-Z1-UB63-140-100-101-1.1-620671_213_1_2_1_1_1_1.csv')
df_ds11 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds11-050-213-Z1-UB63-140-300-301-1.1-620420_213_3_1_1_2_1_1.csv')
df_ds12 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds12-050-213-Z1-UB63-130-100-101-1.1-620558_213_1_2_1_2_1_1.csv')
df_ds13 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds13-050-213-Z1-UB63-130-100-101-1.1-620556_213_3_1_1_2_1_1.csv')
df_ds14 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds14-050-213-Z1-UB63-130-100-101-1.1-620548_213_1_2_1_2_1_1.csv')
df_ds15 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds15-050-213-Z1-UB63-090-100-101-1.1-610653_213_1_2_1_2_1_2.csv')
df_ds16 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds16-050-213-Z1-UB63-130-100-101-1.1-620546_213_1_1_1_2_1_1.csv')
df_ds17 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds17-050-213-Z1-UB63-130-100-101-1.1-620556_213_1_1_1_2_1_1.csv')
df_ds18 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds18-050-213-Z1-UB63-090-100-101-1.1-610649_213_1_1_1_1_1_2.csv')
df_ds19 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds19-050-213-Z1-UB63-090-100-101-1.1-610582_213_1_1_1_2_1_2.csv')
df_ds20 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds20-050-213-Z1-UB63-080-100-101-1.1-610871_213_3_1_1_2_1_1.csv')
df_ds21 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds21-050-213-Z1-UB63-080-200-201-1.1-620542_213_1_1_1_2_1_1.csv')
df_ds22 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds22-050-213-Z1-UB63-080-100-101-1.1-610631_213_1_1_1_1_1_1.csv')
df_ds23 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds23-050-213-Z1-UB63-080-100-101-1.1-610630_213_1_1_1_2_1_1.csv')
df_ds24 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds24-050-213-Z1-UB63-070-200-201-1.1-620645_213_1_1_1_2_1_1.csv')
df_ds25 = pd.read_csv('/Users/guillem/Data/Customers/Daimler/26_datasets_alvaro/ds25-050-213-Z1-UB63-090-100-101-1.1-610582_213_1_1_1_1_1_2.csv')

df_ds25.head()
# Out:
#    location  series line plant  station  robot  controller  tool  StudID  \
# 0        50     213   Z1  UB63       90    100         101   1.1  610582
# 1        50     213   Z1  UB63       90    100         101   1.1  610582
# 2        50     213   Z1  UB63       90    100         101   1.1  610582
# 3        50     213   Z1  UB63       90    100         101   1.1  610582
# 4        50     213   Z1  UB63       90    100         101   1.1  610582
#
#   MeasurementData.MeasurementParameter.StudID.value  ...  \
# 0                            610582_213_1_1_1_1_1_2  ...
# 1                            610582_213_1_1_1_1_1_2  ...
# 2                            610582_213_1_1_1_1_1_2  ...
# 3                            610582_213_1_1_1_1_1_2  ...
# 4                            610582_213_1_1_1_1_1_2  ...
#
#    LMCurrent.CWT_3_FREQ LMCurrent.CWT_3_VALUE LMCurrent.DTW_Distance  \
# 0              0.070652             65.523272               0.640834
# ...

# %% [markdown]
# #### Load references data into a dataframe:

# %%
df_references = pd.read_csv('/Users/guillem/Data/Customers/Daimler/references/tool_reference_stats.csv')

df_references.head()
# Out:
#                                    key_tool           key_extension  \
# 0  h902-040tsb201-kf130.m050g9sub64sps1.1.1  610351_213_1_1_1_2_1_1
# 1  h902-040tsb201-kf130.m050g9sub64sps1.1.1  610351_213_1_1_1_2_1_1
# 2  h902-040tsb201-kf130.m050g9sub64sps1.1.1  610351_213_1_1_1_2_1_1
# 3  h902-040tsb201-kf130.m050g9sub64sps1.1.1  610351_213_1_1_1_2_1_1
# 4  h902-040tsb201-kf130.m050g9sub64sps1.1.1  610351_213_1_1_1_2_1_1
#
#   key_period  num_elements  penetration_ref  penetration_up_limit  \
# 0    2019-11            79        -0.648987             -0.558834
# 1    2019-12          1527        -0.754616             -0.644419
# 2    2020-01          2587        -0.792068             -0.669314
# 3    2020-02          3509        -0.796013             -0.668721
# 4    2020-03          1031        -0.785500             -0.674406
#
#    penetration_low_limit  drop_time_ref  drop_time_up_limit  \
# 0              -0.739140       9.450633           10.043308
# ...

# %% [markdown]
# #### Load all my tools welds data into a dataframe:

# %%
df_all_tools_welds = pd.read_csv('/Users/guillem/Data/Customers/Daimler/anomalies-analysis/resulting_csvs/beckett/my_tools_all_welds.csv')

df_all_tools_welds.head()
# Out:
#    FaultCode  WeldEnergyActual  \
# 0          0              1084
# 1          0              1118
# 2          0               911
# 3          0              1141
# 4          0               933
#
#   MeasurementData.MeasurementParameter.StudID.value  DropTimeActual  \
# 0                            610865_213_3_1_1_2_1_2             8.9
# 1                            610872_213_3_1_1_2_1_1             7.4
# 2                            610583_213_1_1_1_2_1_2            10.0
# 3                            620584_213_1_1_1_1_1_1            10.0
# 4                            610583_213_3_1_1_2_1_2            10.0
#
#    LMPenetrationActual  StickoutActual  LMLiftHeightActual  WeldTimeActual  \
# 0                -0.69            3.40                2.50            73.9
# 1                -0.69            3.03                2.50            74.6
# 2                -0.69            2.98                2.49            60.0
# ...

# %% [markdown]
# Decompose timestamp field into multiple new fields year, month

# %%
df_all_tools_welds['year'] = df_all_tools_welds.apply(lambda row: row.timestamp[0:4], axis=1)
df_all_tools_welds['month'] = df_all_tools_welds.apply(lambda row: row.timestamp[5:7], axis=1)

df_all_tools_welds.head()
# Out:
#    FaultCode  WeldEnergyActual  \
# 0          0              1084
# 1          0              1118
# 2          0               911
# 3          0              1141
# 4          0               933
#
#   MeasurementData.MeasurementParameter.StudID.value  DropTimeActual  \
# 0                            610865_213_3_1_1_2_1_2             8.9
# 1                            610872_213_3_1_1_2_1_1             7.4
# 2                            610583_213_1_1_1_2_1_2            10.0
# 3                            620584_213_1_1_1_1_1_1            10.0
# 4                            610583_213_3_1_1_2_1_2            10.0
#
#    LMPenetrationActual  StickoutActual  LMLiftHeightActual  WeldTimeActual  \
# 0                -0.69            3.40                2.50            73.9
# 1                -0.69            3.03                2.50            74.6
# 2                -0.69            2.98                2.49            60.0
# ...

# %% [markdown]
# 1) Add distance from the average value (monthly value) to the global welds dataframe

# %% [markdown]
# Generate chronologically ordered (indexed) dataframes for each tool (start with 1 tool)
# Analyse chronological holes
# Re-Index dataframe considering chronological holes

# %% [markdown]
# 2) Join 1 dataset rows with it's tool welds data calculating features: avg_distance_percent_10welds/50w/100w/500w, offlimit_percent_avg_10w/50w/100w/500w

# %% [markdown]
# ##### Start working with one tool and dataset
#
# Dataset: ds8
#
# Extension: 610456_213_3_1_1_1_1_1
#
# UniqueID: h902-110tsb101-kf130.m050g9sub64sps3.1.1

# %% [markdown]
# ###### 0) Extract and order all welds from the given tool into a new dataframe

# %%
# filter and order chronologically welds from current tool in 2020
df_my_tool = df_all_tools_welds[(df_all_tools_welds.uniqueID == "h902-110tsb101-kf130.m050g9sub64sps3.1.1") & (df_all_tools_welds.year == "2020")].sort_values(by=['timestamp'])

df_my_tool = df_my_tool.rename(columns={'MeasurementData.MeasurementParameter.StudID.value': 'extensionID'})

print(df_my_tool.shape)
# Out:
# (620851, 14)

# %%
df_my_tool.head()
# Out:
#          FaultCode  WeldEnergyActual             extensionID  DropTimeActual  \
# 4969726          0              1048  620522_213_1_1_1_2_1_1            10.3
# 4969728          0              1155  620508_213_1_1_1_2_1_1            10.9
# 4524102          0              1127  620392_213_1_1_1_2_1_1            10.5
# 4524099          0              1055  620482_213_1_1_1_2_1_1            12.0
# 4524104          0              1067  620786_213_1_1_1_2_1_1            10.3
#
#          LMPenetrationActual  StickoutActual  LMLiftHeightActual  \
# 4969726                -0.93            3.32                1.50
# 4969728                -0.95            3.02                1.50
# 4524102                -0.85            3.46                1.50
# 4524099                -1.28            3.49                1.52
# 4524104                -0.86            3.00                1.50
#
#          WeldTimeActual                                  uniqueID  \
# ...

# %%
# add reference and limits columns

def get_pen_average(y, m, uniqueID, extension, df):
    pen_avg = df[(df.key_period[0:4] == y) & (df.key_period[5:7] == m) & (df.key_tool == uniqueID) & (df.key_extension == extension)]['penetration_ref']
    return pen_avg

df_my_tool['penetration_avg'] = df_my_tool.apply(lambda row: get_pen_average(row['year'], row['month'], row['uniqueID'], row['extensionID'], df_references), axis = 1)

# df_my_tool['penetration_low_2sig'] =
# df_my_tool['penetration_up_2sig'] =
# df_my_tool['drop_time_avg'] =
# df_my_tool['drop_time_low_2sig'] =
# df_my_tool['drop_time_up_2sig'] =
# df_my_tool['drop_time_avg'] =
# df_my_tool['drop_time_low_2sig'] =
# df_my_tool['drop_time_up_2sig'] =
# df_my_tool['voltage_avg'] = 
# df_my_tool['voltage_up_2sig'] = 
# df_my_tool['voltage_low_2sig'] = 
# df_my_tool['time_avg'] = 
# df_my_tool['time_up_2sig'] = 
# df_my_tool['time_low_2sig'] = 
# df_my_tool['lift_avg'] = 
# df_my_tool['lift_up_2sig'] = 
# df_my_tool['lift_low_2sig'] = 
# df_my_tool['current_avg'] = 
# df_my_tool['current_up_2sig'] = 
# df_my_tool['current_low_2sig'] = 
# df_my_tool['enery_avg'] = 
# df_my_tool['energy_up_2sig'] = 
# df_my_tool['energy_low_2sig'] = 
# df_my_tool['stickout_avg'] = 
# df_my_tool['stickout_up_2sig'] = 
# df_my_tool['stickout_low_2sig'] = 
''

head(df_my_tool)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-97c2a0a0bc7b> in <module>
#       5     return pen_avg
#       6
# ----> 7 df_my_tool['penetration_avg'] = df_my_tool.apply(lambda row: get_pen_average(row['year'], row['month'], row['uniqueID'], row['extensionID'], df_references), axis = 1)
#       8
#       9 # df_my_tool['penetration_low_2sig'] =
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
# ...
